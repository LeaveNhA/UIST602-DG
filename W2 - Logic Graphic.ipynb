# %%
except
    err_ => 
        plt = import '/matplotlib/pyplot'
        pd = import '/pandas'
        np = import '/numpy'
    err_ :: ModuleNotFoundError =>
            print "Kütüphaneler yüklü olmayabilir."
# Out:
# <module 'numpy' from '/Users/sckn/.pyenv/versions/3.6.15/lib/python3.6/site-packages/numpy/__init__.py'>

# %%
logit = x -> np.log(x / (1 - x))
# Out:
# <function logit at 0x1077bbe18>

# %%
x = np.arange 0.001 0.999 0.0001
y = (map logit x) |> list |> np.array

[x, y]
# Out:
# [array([0.001 , 0.0011, 0.0012, ..., 0.9987, 0.9988, 0.9989]), array([-6.90675478, -6.81134449, -6.724233  , ...,  6.64409017,
#         6.724233  ,  6.81134449])]

# %%
figür = plt.figure!

plt.plot x y
plt.xlabel "Olasılık"
plt.ylabel "Logit"

figür
# Out:
# Figure(640x480)
