# %%
except
    err_ => 
        plt = import '/matplotlib/pyplot'
        pd = import '/pandas'
        np = import '/numpy'
    err_ :: ModuleNotFoundError =>
            print "Kütüphaneler yüklü olmayabilir."
# Out:
# <module 'numpy' from '/Users/sckn/.pyenv/versions/3.6.15/lib/python3.6/site-packages/numpy/__init__.py'>

# %%
sigmoid = x -> 1 / (1 + (np.exp (-x)))
# Out:
# <function sigmoid at 0x118d6a2f0>

# %%
x = np.arange -7 7 1e-5
y = (map sigmoid x) |> list |> np.array

[x, y]
# Out:
# [array([-7.     , -6.99999, -6.99998, ...,  6.99997,  6.99998,  6.99999]), array([9.11051194e-04, 9.11060297e-04, 9.11069399e-04, ...,
#        9.99088921e-01, 9.99088931e-01, 9.99088940e-01])]

# %%
figür = plt.figure!

plt.plot x y
plt.xlabel "Olasılık"
plt.ylabel "Logit"

figür
# Out:
# Figure(640x480)
